# %% [markdown]
# pytorch深度学习实践课件等<br>
# 链接: https://pan.baidu.com/s/1njQxoIW5SQrtT41SOrY_HA?pwd=b9va 提取码: b9va 复制这段内容后打开百度网盘手机App，操作更方便哦

# %%
x = torch.tensor(2.0, requires_grad=True)
y = x*2
z = y*y
z.backward()
print(y.requires_grad)
print(x.grad)
# Out:
# True
# tensor(16.)
