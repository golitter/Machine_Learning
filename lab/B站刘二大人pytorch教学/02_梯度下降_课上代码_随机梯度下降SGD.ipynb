# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# SGD算法是从样本中随机抽出一组，训练后按梯度更新一次，然后再抽取一组，再更新一次，在样本量及其大的情况下，可能不用训练完所有的样本就可以获得一个损失值在可接受范围之内的模型了。（重点：每次迭代使用一组样本。）<br>
# https://blog.csdn.net/qq_58146842/article/details/121280968?ops_request_misc=%257B%2522request%255Fid%2522%253A%2522168947650516800211536248%2522%252C%2522scm%2522%253A%252220140713.130102334..%2522%257D&request_id=168947650516800211536248&biz_id=0&utm_medium=distribute.pc_search_result.none-task-blog-2~all~top_positive~default-1-121280968-null-null.142^v88^insert_down28v1,239^v2^insert_chatgpt&utm_term=SGD&spm=1018.2226.3001.4187

# %%
x_data = [1.0, 2.0, 3.0]
y_data = [2.0, 4.0, 6.0]

w = 1.0
loss_list = []
def forward(x):
    return x * w

def loss(x,y):
    y_pred = forward(x)
    return (y_pred - y) ** 2

def gradient(x, y):
    return 2 * x * ( w * x - y)

print("Predict (before training)", 4, forward(4))
for epoch in range(100):
    for x, y in zip(x_data, y_data):
        grad = gradient(x,y)
        w = w - 0.01 * grad
        print("\tgrad: ",x, y, grad)
        l = loss(x,y)
        loss_list.append(l)
    print("Progress: ", epoch, "w = ", w, "loss = ", l)
    # loss_list.append(l)

print("Predict (after training)", 4, forward(4))
# Out:
# Predict (before training) 4 4.0
# 	grad:  1.0 2.0 -2.0
# 	grad:  2.0 4.0 -7.84
# 	grad:  3.0 6.0 -16.2288
# Progress:  0 w =  1.260688 loss =  4.919240100095999
# 	grad:  1.0 2.0 -1.478624
# 	grad:  2.0 4.0 -5.796206079999999
# 	grad:  3.0 6.0 -11.998146585599997
# Progress:  1 w =  1.453417766656 loss =  2.688769240265834
# 	grad:  1.0 2.0 -1.093164466688
# 	grad:  2.0 4.0 -4.285204709416961
# 	grad:  3.0 6.0 -8.87037374849311
# Progress:  2 w =  1.5959051959019805 loss =  1.4696334962911515
# 	grad:  1.0 2.0 -0.8081896081960389
# 	grad:  2.0 4.0 -3.1681032641284723
# 	grad:  3.0 6.0 -6.557973756745939
# Progress:  3 w =  1.701247862192685 loss =  0.8032755585999681
# 	grad:  1.0 2.0 -0.59750427561463
# 	grad:  2.0 4.0 -2.3422167604093502
# 	grad:  3.0 6.0 -4.848388694047353
# Progress:  4 w =  1.7791289594933983 loss =  0.43905614881022015
# 	grad:  1.0 2.0 -0.44174208101320334
# 	grad:  2.0 4.0 -1.7316289575717576
# 	grad:  3.0 6.0 -3.584471942173538
# ...

# %%
plt.plot(range(1,301), loss_list)
plt.ylabel("cost")
plt.xlabel("epoch")
plt.show()
