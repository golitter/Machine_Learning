# %%
"""
任务：将图像按照物体的类别分割成不同的区域
等价于：对每个像素进行分类
# https://blog.csdn.net/jiaoyangwm/article/details/125717563?ops_request_misc=%257B%2522request%255Fid%2522%253A%2522169206842116800211552572%2522%252C%2522scm%2522%253A%252220140713.130102334..%2522%257D&request_id=169206842116800211552572&biz_id=0&utm_medium=distribute.pc_search_result.none-task-blog-2~all~top_positive~default-1-125717563-null-null.142^v92^insert_down1&utm_term=%E8%AF%AD%E4%B9%89%E5%88%86%E5%89%B2&spm=1018.2226.3001.4187

"""
