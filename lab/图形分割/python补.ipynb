# %%
# https://blog.csdn.net/qq_37635772/article/details/107285189?ops_request_misc=&request_id=&biz_id=102&utm_term=%E6%B7%B1%E5%BA%A6%E5%AD%A6%E4%B9%A0%20python%E7%9F%A5%E8%AF%86&utm_medium=distribute.pc_search_result.none-task-blog-2~all~sobaiduweb~default-1-107285189.142^v92^insert_down1&spm=1018.2226.3001.4187


# 在 Python 中，enumerate 是一个内置函数，它用于在迭代过程中同时获得元素的索引和值。

my_list = ['apple', 'banana', 'orange']
for index, value in enumerate(my_list):
    print(index, value)
my_list = [ 3,2,1]
for i,val in enumerate(my_list):
    print(i,val)
# Out:
# 0 apple
# 1 banana
# 2 orange
# 0 3
# 1 2
# 2 1

# %%
""" 
文件处理
注意 . ../ /
"""
# # 打开一个文件
# f = open("./test/fo1.txt", "w")
# f.write("Python 是一种非常好的语言。\
# 我喜欢Python!!\
# ")
# # 关闭打开的文件
# f.close()

# 比如r+、w+、a+
# f = open("./test/foo.txt", "r")
# 读写模式 print(f.read())
# f.write("dklfjdkfj\
# dfkj\
# dkfj\
# 优化")
# print(f.read())
# str = f.readline()
print(str)
# f.close()
# help(open)
# Out:
# dklfjdkfjdfkjdk

# %%
name = "优化"
# 这段代码使用 f-string 格式化字符串，将变量 name 的值插入到字符串中。
print(f"Hello {name}")
# Out:
# Hello 优化

# %%
ab = 343
def add(x:int):
    global ab
    ab = 3
    x += 1

i = 3
add(i)
print(i,ab)
# Out:
# 3 3

# %%
# os 模块
import os

# 当前目录
print(os.getcwd())
# 切换目录
# os.chdir("D:/")
print(os.getcwd())

# 获取所有的环境变量
print(os.environ)

# os.getlogin()返回通过控制终端进程进行登录的用户名
print(os.getlogin())
# os.name 返回python运行的环境系统
print(os.name)
# https://blog.csdn.net/qq_52007481/article/details/126918076?ops_request_misc=%257B%2522request%255Fid%2522%253A%2522169199213616800227448617%2522%252C%2522scm%2522%253A%252220140713.130102334..%2522%257D&request_id=169199213616800227448617&biz_id=0&utm_medium=distribute.pc_search_result.none-task-blog-2~all~top_positive~default-2-126918076-null-null.142^v92^insert_down1&utm_term=python%20os&spm=1018.2226.3001.4187
# Out:
# D:\
# D:\
# ...

# %%
# os.mkdir("abcdef")
print(os.getcwd())
# print(os.cwd())
# print(os.path())
# import sys 
# current_directory = os.path.dirname(os.path.abspath(__file__))
# print(current_directory)
# print(os.path.abspath(__file__))
# print(os.path.dirname(__file__))
# Out:
# D:\
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 9
#       2 print(os.getcwd())
#       3 # print(os.cwd())
#       4 # print(os.path())
#       5 # import sys
#       6 # current_directory = os.path.dirname(os.path.abspath(__file__))
#       7 # print(current_directory)
#       8 # print(os.path.abspath(__file__))
# ----> 9 print(os.path.dirname(__file__))
#
# NameError: name '__file__' is not defined
