# %%
# https://blog.csdn.net/weixin_36474809/article/details/87931260?ops_request_misc=%257B%2522request%255Fid%2522%253A%2522169216688016800182777301%2522%252C%2522scm%2522%253A%252220140713.130102334..%2522%257D&request_id=169216688016800182777301&biz_id=0&utm_medium=distribute.pc_search_result.none-task-blog-2~all~top_positive~default-1-87931260-null-null.142^v92^insert_down1&utm_term=unet%E8%AE%BA%E6%96%87&spm=1018.2226.3001.4449

# %%
a1, a2 = list(map(int, input().split()))
print(a1,a2)
# Out:
# 1 2
