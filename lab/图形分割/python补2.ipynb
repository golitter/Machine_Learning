# %%
import os 
print(os.getcwd())
# os.mkdir("./abcd")
# os.rmdir("./abcd/")
# os.makedirs("./ab/cd/edf/b")
# os.removedirs("./ab/cd/edf/b/")


# os.listdir(".")

# os.makedirs("./ab/df")
# os.rename("./ab/df", "ab/aaaaaa")
# print(os.listdir("./ab"))

# os.removedirs("./ab/aaaaaa")

# print(os.path.abspath("./Images_C/三个分割.png"))
print(os.path.exists("./Images_C/三个分割.png"))
print(os.path.exists("./abdc"))

print(os.path.isdir("./Images_C/"))
print(os.path.isfile("./Images_C/三个分割.png"))
print(os.path.basename("./Images_C/三个分割.png"))
print(os.path.dirname("./Images_C/三个分割.png"))

print(os.path.join("test", "foo.txt"))
fn = os.path.join("test", "foo.txt")
print(os.path.isfile(fn))
print(os.path.abspath(fn))


print(os.path.split(fn))
print(os.path.splitext(fn))
# Out:
# e:\Undergraduate\School\Scientific_research\ML\Machine_Learning\lab\图形分割
# True
# False
# True
# True
# 三个分割.png
# ./Images_C
# test\foo.txt
# True
# e:\Undergraduate\School\Scientific_research\ML\Machine_Learning\lab\图形分割\test\foo.txt
# ('test', 'foo.txt')
# ('test\\foo', '.txt')

# %%
print(os.listdir("."))
lit = os.listdir(".")
for idx, it in enumerate(lit):
    print(idx, end=" ")
    pj = os.path.join(".", it)
    print(pj)
# Out:
# ['Images_C', 'python补.ipynb', 'python补2.ipynb', 'test', '图形分割基础概念.ipynb', '语义分割.ipynb', '语义分割算法基础__tjzhx.ipynb']
# 0 .\Images_C
# 1 .\python补.ipynb
# 2 .\python补2.ipynb
# 3 .\test
# 4 .\图形分割基础概念.ipynb
# 5 .\语义分割.ipynb
# 6 .\语义分割算法基础__tjzhx.ipynb
